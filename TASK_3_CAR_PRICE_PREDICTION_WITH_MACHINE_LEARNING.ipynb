# %% [markdown]
# <a href="https://colab.research.google.com/github/Debottam20/OIBSIP/blob/main/TASK_3_CAR_PRICE_PREDICTION_WITH_MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Oasis Infobyte Data Science Internship**

# %% [markdown]
# ## Task 3: Car Price Prediction with Machine Learning

# %% [markdown]
# ### **Name: Debottam Mukherjee**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 1. Import Libraries and Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('car data.csv')

# %%
print (df)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %% [markdown]
# ### 2. Exploratory Data Analysis
#
# 2.1 First 10 rows of dataset

# %%
print(" First 10 rows of the dataset:")
df.head(10)
# Out:
#  First 10 rows of the dataset:
#         Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# 5       Dealer       Manual      0
# 6       Dealer       Manual      0
# 7       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
#    2.2  Summary Statistics

# %%
df.describe().style.format(precision=2).background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_c4746_row0_col0 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_c4746_row0_col1, #T_c4746_row0_col2, #T_c4746_row0_col4, #T_c4746_row1_col0, #T_c4746_row4_col0, #T_c4746_row5_col0, #T_c4746_row6_col0, #T_c4746_row7_col0, #T_c4746_row7_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c4746_row0_col3, #T_c4746_row1_col4, #T_c4746_row2_col0, #T_c4746_row2_col4, #T_c4746_row3_col1, #T_c4746_row3_col2, #T_c4746_row3_col3, #T_c4746_row3_col4, #T_c4746_row4_col1, #T_c4746_row4_col2, #T_c4746_row4_col4, #T_c4746_row5_col4, #T_c4746_row6_col4 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_c4746_row1_col1 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_c4746_row1_col2, #T_c4746_row5_col2, #T_c4746_row6_col1 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_c4746_row1_col3 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_c4746_row2_col1 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_c4746_row2_col2, #T_c4746_row4_col3 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_c4746_row2_col3 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_c4746_row3_col0 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_c4746_row5_col1, #T_c4746_row7_col4 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_c4746_row5_col3 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_c4746_row6_col2 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_c4746_row6_col3 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_c4746_row7_col1 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_c4746_row7_col2 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# </style>
# <table id="T_c4746" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4746_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_c4746_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_c4746_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_c4746_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_c4746_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4746_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c4746_row0_col0" class="data row0 col0" >301.00</td>
#       <td id="T_c4746_row0_col1" class="data row0 col1" >301.00</td>
#       <td id="T_c4746_row0_col2" class="data row0 col2" >301.00</td>
#       <td id="T_c4746_row0_col3" class="data row0 col3" >301.00</td>
#       <td id="T_c4746_row0_col4" class="data row0 col4" >301.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c4746_row1_col0" class="data row1 col0" >2013.63</td>
#       <td id="T_c4746_row1_col1" class="data row1 col1" >4.66</td>
#       <td id="T_c4746_row1_col2" class="data row1 col2" >7.63</td>
#       <td id="T_c4746_row1_col3" class="data row1 col3" >36947.21</td>
#       <td id="T_c4746_row1_col4" class="data row1 col4" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c4746_row2_col0" class="data row2 col0" >2.89</td>
#       <td id="T_c4746_row2_col1" class="data row2 col1" >5.08</td>
#       <td id="T_c4746_row2_col2" class="data row2 col2" >8.64</td>
#       <td id="T_c4746_row2_col3" class="data row2 col3" >38886.88</td>
#       <td id="T_c4746_row2_col4" class="data row2 col4" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c4746_row3_col0" class="data row3 col0" >2003.00</td>
#       <td id="T_c4746_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_c4746_row3_col2" class="data row3 col2" >0.32</td>
#       <td id="T_c4746_row3_col3" class="data row3 col3" >500.00</td>
#       <td id="T_c4746_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c4746_row4_col0" class="data row4 col0" >2012.00</td>
#       <td id="T_c4746_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_c4746_row4_col2" class="data row4 col2" >1.20</td>
#       <td id="T_c4746_row4_col3" class="data row4 col3" >15000.00</td>
#       <td id="T_c4746_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c4746_row5_col0" class="data row5 col0" >2014.00</td>
#       <td id="T_c4746_row5_col1" class="data row5 col1" >3.60</td>
#       <td id="T_c4746_row5_col2" class="data row5 col2" >6.40</td>
#       <td id="T_c4746_row5_col3" class="data row5 col3" >32000.00</td>
#       <td id="T_c4746_row5_col4" class="data row5 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_c4746_row6_col0" class="data row6 col0" >2016.00</td>
#       <td id="T_c4746_row6_col1" class="data row6 col1" >6.00</td>
#       <td id="T_c4746_row6_col2" class="data row6 col2" >9.90</td>
#       <td id="T_c4746_row6_col3" class="data row6 col3" >48767.00</td>
#       <td id="T_c4746_row6_col4" class="data row6 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c4746_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_c4746_row7_col0" class="data row7 col0" >2018.00</td>
#       <td id="T_c4746_row7_col1" class="data row7 col1" >35.00</td>
#       <td id="T_c4746_row7_col2" class="data row7 col2" >92.60</td>
#       <td id="T_c4746_row7_col3" class="data row7 col3" >500000.00</td>
#       <td id="T_c4746_row7_col4" class="data row7 col4" >3.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# 2.3 Now let's check for missing values

# %%
print('The Missing Values are:')
df.isnull().sum()
# Out:
# The Missing Values are:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# 2.4 Column Data Types

# %%
print(" Data types of columns are:")
print(df.dtypes)
# Out:
#  Data types of columns are:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object

# %% [markdown]
# 2.5  Now in this step we will check for duplicates

# %%
print('The Duplicate Values are:')
df.duplicated().sum()
# Out:
# The Duplicate Values are:
# 2

# %%
# Dropping the duplicate values
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 3. Visualizing data and conducting exploratory analysis.

# %% [markdown]
# 3.1 Now in this step we are checking for Outliers

# %%
# Checking for outliers using boxplots
plt.figure(figsize=(10, 6))
sns.boxplot(df['Selling_Price'],palette='pastel')
plt.title('Boxplot of Selling Price')
plt.show()

# %% [markdown]
# 3.2  Correlation Heatmap

# %%
numerical_columns = ['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Owner']
numerical_df = df[numerical_columns]
correlation_matrix = numerical_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='BuPu', fmt=".2f")
plt.title('Correlation Heatmap (Numerical Columns)')
plt.show()

# %% [markdown]
# ### Summary
#
# ### Strong Positive Correlation:
# Selling Price and Present Price show a highly positive correlation, implying a nearly perfect linear connection. This aligns with the expectation that the present market value strongly influences the selling price
# ### Influence of Year:
# Year exhibits a weak negative correlation with Selling Price, Present Price, and Driven_Kms. Newer cars (with lower Year values) generally command higher selling prices, lower present prices, and fewer driven kilometers.
# ### Importance of Mileage:
# Driven_Kms demonstrates a weak negative correlation with Selling Price and Present Price. Cars with lower mileage (lower Driven_Kms values) typically sell for higher prices.

# %% [markdown]
# 3.3 Distribution of Various Numeric Features

# %%
numerical_features = ['Year', 'Driven_kms', 'Selling_Price', 'Present_Price']
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.displot(data=df, x=feature, kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %% [markdown]
# 3.4 Scatter Plots

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Driven_kms', y='Selling_Price', data=df)
plt.title('Relationship between Driven_kms and Selling_Price')
plt.show()

# %% [markdown]
# ~ The plot suggests a negative correlation between Driven_Kms and Selling_Price. Cars with higher driven kilometers tend to sell for less.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Present_Price', y='Selling_Price', data=df)
plt.title('Relationship between Present_Price and Selling_Price')
plt.xlabel('Present Price')
plt.ylabel('Selling Price')

plt.show()

# %% [markdown]
# ### Findings:
#
# ### Price Association:
# The data indicates a robust positive correlation between Present Price and Selling Price. Vehicles with a higher present market value tend to fetch higher selling prices.
# ### Market Impact:
# This implies that the present market value significantly affects the ultimate selling price.

# %% [markdown]
# 3.5 Count Plots of Categorical Features

# %%
colors = sns.color_palette("Set1")
categorical_features = ['Fuel_Type', 'Selling_type', 'Transmission', 'Owner']

for feature in categorical_features:
    plt.figure(figsize=(13, 4))
    sns.countplot(x=feature, data=df,color='yellow')
    plt.title(f'Frequency of {feature}', fontsize=16, color='darkgreen', fontweight='bold')
    plt.xlabel(f'{feature}', fontsize=14, color='purple')
    plt.ylabel('Frequency', fontsize=14, color='blue')
    plt.xticks(fontsize=12, rotation=45)
    plt.yticks(fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# 3.6 Top 20 Car Models by Frequency

# %%
n = 20
top_car_models = df['Car_Name'].value_counts().head(n)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_car_models.values, y=top_car_models.index)
plt.title(f'Top {n} Car Models by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3.7 Top 20 Car Models by Average Price

# %%
avg_prices_by_car = df.groupby('Car_Name')['Selling_Price'].mean().sort_values(ascending=False)

n = 20  # Number of top car models to plot
top_car_models = avg_prices_by_car.head(n)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_car_models.values, y=top_car_models.index,palette='summer')
plt.title(f'Top {n} Car Models by Average Price')
plt.xlabel('Average Price')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Data Cleaning and Data Transformation

# %% [markdown]
# 4.1 Check Features

# %%
print(df['Fuel_Type'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64

# %%
print(df['Selling_type'].value_counts())
# Out:
# Selling_type
# Dealer        193
# Individual    106
# Name: count, dtype: int64

# %%
print(df['Transmission'].value_counts())
# Out:
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %% [markdown]
# 4.2 Encode categorical features

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %% [markdown]
# ### 5. Prediction

# %% [markdown]
# 5.1 Define target variable

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
Y = df['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [299 rows x 7 columns]

# %%
Y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %% [markdown]
# 5.2 Train and Test Data

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# 5.3 Initialize the linear regression model

# %%
# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 5.3 Evaluation of Model

# %%
# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 6.675444100493416
# R-squared: 0.7409934356413092

# %% [markdown]
# 5.4 Predictions

# %%
# Make predictions
new_car = [[2022, 20000, 0, 1, 1, 0, 0]]  # Example new car data
predicted_price = model.predict(new_car)
print('Predicted Selling Price:', predicted_price[0])
# Out:
# Predicted Selling Price: 8829.49338250246
